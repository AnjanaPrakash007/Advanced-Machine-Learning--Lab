# %%
import numpy as np
import tensorflow as tf
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input,Dense,Conv2D,MaxPooling2D,Flatten
# loading data
(x_train,y_train),(x_test,y_test)=cifar10.load_data()
# get the number of classes
n_classes=len(np.unique(y_train))
# normalize pixel values bet 0-1
x_train,x_test=x_train/255.0,x_test/255.0
# get input shape
n_features=x_train.shape[1:]
def build_neural_network(n_features,n_classes):
    # define input layer
    inputs=Input(shape=n_features)
    # add cn layers and pooling layers
    network_1=Conv2D(32,kernel_size=(3,3),activation='relu')(inputs)
    network_2=Conv2D(64,kernel_size=(3,3),activation='relu')(network_1)
    network_3=MaxPooling2D(pool_size=(2,2))(network_2)
    network_4=Conv2D(128,kernel_size=(3,3),activation='relu')(network_3)
    network_5=Conv2D(256,kernel_size=(3,3),activation='relu')(network_4)
    network_6=MaxPooling2D(pool_size=(2,2))(network_5)
    # flatten and add fully connected layers
    network_7=Flatten()(network_6)
    network_8=Dense(128,activation='relu')(network_7)
    # define output layer
    output=Dense(n_classes,activation='softmax')(network_8)
    # create model
    model=Model(inputs=inputs,outputs=output)
    return model
# build model'
network=build_neural_network(n_features,n_classes)
# compile model
network.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=[tf.keras.metrics.CategoricalAccuracy()]
)
network.summary()

    

    
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input,Dense,Conv2D,MaxPooling2D,Flatten
# loading data
(x_train,y_train),(x_test,y_test)=cifar10.load_data()
# get the number of classes
n_classes=len(np.unique(y_train))
# normalize pixel values bet 0-1
x_train,x_test=x_train/255.0,x_test/255.0
# get input shape
n_features=x_train.shape[1:]
def build_neural_network(n_features,n_classes):
    # define input layer
    inputs=Input(shape=n_features)
    # add cn layers and pooling layers
    network_1=Conv2D(32,kernel_size=(3,3),activation='relu')(inputs)
    network_2=Conv2D(64,kernel_size=(3,3),activation='relu')(x)
    network_3=MaxPooling2D(pool_size=(2,2))(x)
    network_4=Conv2D(128,kernel_size=(3,3),activation='relu')(x)
    network_5=Conv2D(256,kernel_size=(3,3),activation='relu')(x)
    network_6=MaxPooling2D(pool_size=(2,2))(x)
    # flatten and add fully connected layers
    network_7=Flatten()(x)
    network_8=Dense(128,activation='relu')(x)
    # define output layer
    output=Dense(n_classes,activation='softmax')(x)
    # create model
    model=Model(inputs=inputs,outputs=output)
    return model
# build model'
network=build_neural_network(n_features,n_classes)
# compile model
network.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=[tf.keras.metrics.CategoricalAccuracy()]
)
network.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_2 (Conv2D)           (None, 30, 30, 32)        896
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 64)        18496
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 64)        0
#  D)
#
#  conv2d_4 (Conv2D)           (None, 12, 12, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 10, 10, 256)       295168
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 5, 256)         0
#  g2D)
#
#  flatten (Flatten)           (None, 6400)              0
#
#  dense (Dense)               (None, 128)               819328
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 1209034 (4.61 MB)
# Trainable params: 1209034 (4.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 76
#      74     return model
#      75 # build model'
# ---> 76 network=build_neural_network(n_features,n_classes)
#      77 # compile model
#      78 network.compile(
#      79     optimizer=tf.keras.optimizers.Adam(),
#      80     loss=tf.keras.losses.CategoricalCrossentropy(),
#      81     metrics=[tf.keras.metrics.CategoricalAccuracy()]
#      82 )
#
# Cell In[3], line 62, in build_neural_network(n_features, n_classes)
#      60 # add cn layers and pooling layers
#      61 network_1=Conv2D(32,kernel_size=(3,3),activation='relu')(inputs)
# ---> 62 network_2=Conv2D(64,kernel_size=(3,3),activation='relu')(x)
#      63 network_3=MaxPooling2D(pool_size=(2,2))(x)
#      64 network_4=Conv2D(128,kernel_size=(3,3),activation='relu')(x)
#
# NameError: name 'x' is not defined
